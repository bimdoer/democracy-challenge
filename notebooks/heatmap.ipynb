# %% [markdown]
# # Heatmap

# %% [markdown]
# ## Import

# %%
from visualisierungen import heatmap
import pandas as pd

# %%
df = pd.read_csv("../data/processed/swissvotes_processed.csv")
df.head()
# Out:
#    anr       datum  legisjahr             rechtsform_name  \
# 0  1.0  1848-09-12  1848-1851  Obligatorisches Referendum
# 1  2.0  1866-01-14  1863-1866  Obligatorisches Referendum
# 2  3.0  1866-01-14  1863-1866  Obligatorisches Referendum
# 3  4.0  1866-01-14  1863-1866  Obligatorisches Referendum
# 4  5.0  1866-01-14  1863-1866  Obligatorisches Referendum
#
#                                         titel_kurz_d  anzahl  beteiligung  \
# 0  Bundesverfassung der schweizerischen Eidgenoss...       1          NaN
# 1                                   Mass und Gewicht       9          NaN
# 2  Gleichstellung der Juden und Naturalisierten m...       9          NaN
# 3  Stimmrecht der Niedergelassenen in Gemeindeang...       9          NaN
# 4  Besteuerung und zivilrechtliche Verhältnisse d...       9          NaN
#
#    annahme  volkja-proz  berecht  ...  p-vdk  p-sodk  p-endk p-fdk p-edk  \
# 0      1.0        72.83      NaN  ...    NaN     NaN     NaN   NaN   NaN
# ...

# %%
heatmap(df, xlabel=" ", ylabel="", vmax=None, cmap=None, figsize=(6, 7), fmt=".0f", xlabels=None, ylabels=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 heatmap(df, xlabel="", ylabel="", vmax=None, cmap=None, figsize=(6, 7), fmt=".0f", xlabels=None, ylabels=None)
#
# File c:\Users\manuel\Documents\github\Praediktive-Direkte-Demokratie\notebooks\visualisierungen.py:165, in heatmap(pivot, xlabel, ylabel, vmax, cmap, figsize, fmt, xlabels, ylabels)
#     163 sns.set_style("whitegrid")
#     164 plt.figure(figsize=figsize)
# --> 165 ax = sns.heatmap(
#     166     pivot, cmap=cmap,
#     167     vmin=0, vmax=vmax,
#     168     linewidths=0.1,
#     169     annot=True, fmt=fmt,
#     170     annot_kws={"size": 9})
#     172 if xlabels:
#     173     ax.set_xticklabels(xlabels)
#
# ...
